# %%
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.applications.vgg16 import preprocess_input

model = tf.keras.models.load_model("cnn_animals10_VGG16_finetuned.h5")

img_path = "test_images/dog3.jpeg" 

# Load image
img_bgr = cv2.imread(img_path)
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)  # this is for display
img_resized = cv2.resize(img_rgb, (160, 160))       # for model input

# Preprocess for VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
img = preprocess_input(img_resized)
img = np.expand_dims(img, axis=0)

# Predict
prediction = model.predict(img)
predicted_class = class_names[np.argmax(prediction)]

print("Predicted class:", predicted_class)

# Show original image
plt.imshow(img_rgb)
plt.title(f"Predicted: {predicted_class}")
plt.axis('off')
# Out:
# 1/1 [==============================] - 0s 208ms/step
# Predicted class: dog
# 2025-07-24 17:49:48.275322: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# (-0.5, 309.5, 161.5, -0.5)

# %%
print(prediction)
# Out:
# [[1.0626326e-05 1.0706841e-05 3.9839551e-16 5.3683603e-14 1.7412902e-06
#   4.0439576e-07 9.9972636e-01 2.5016753e-04 6.0601501e-14 2.6817968e-12]]
